# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('WineData/winemag-data-130k-v2.csv')
# Out:
# /home/david/.virtualenvs/datascience10/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
df=df[['country','designation', 'points',
       'price', 'province', 'region_1', 'region_2', 'taster_name',
       'taster_twitter_handle', 'title', 'variety', 'winery']]

# %%
df
# Out:
#             country                                        designation points  \
# 0             Italy                                       Vulkà Bianco     87
# 1          Portugal                                           Avidagos     87
# 2                US                                                NaN     87
# 3                US                               Reserve Late Harvest     87
# 4                US                 Vintner's Reserve Wild Child Block     87
# 5             Spain                                       Ars In Vitro     87
# 6             Italy                                            Belsito     87
# 7            France                                                NaN     87
# 8           Germany                                              Shine     87
# 9            France                                        Les Natures     87
# 10               US                                     Mountain Cuvée     87
# ...

# %%
df.groupby('country')['taster_name'].count()
# Out:
# country
# Argentina                  3792
# Armenia                       2
# Australia                  2037
# Austria                    3329
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      256
# Chile                      4357
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    21814
# Georgia                      86
# Germany                    2134
# Greece                      466
# Hungary                     145
# India                         9
# Israel                      498
# Italy                     11041
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       65
# Moldova                      59
# Morocco                      28
# ...

# %%
mask_US=df.country == 'US'
mask_tester=df.taster_name == 'Jim Gordon'

# %%
US=df.loc[mask_US, : ]

# %%
US_data=US[['country','price','taster_name','taster_twitter_handle']]

US_data
# Out:
#        country price         taster_name taster_twitter_handle
# 2           US    14        Paul Gregutt           @paulgwine
# 3           US    13  Alexander Peartree                   NaN
# 4           US    65        Paul Gregutt           @paulgwine
# 10          US    19      Virginie Boone               @vboone
# 12          US    34      Virginie Boone               @vboone
# 14          US    12       Matt Kettmann         @mattkettmann
# 19          US    32  Alexander Peartree                   NaN
# 20          US    23  Alexander Peartree                   NaN
# 21          US    20        Paul Gregutt           @paulgwine
# 23          US    22       Matt Kettmann         @mattkettmann
# 25          US    69      Virginie Boone               @vboone
# 29          US    16      Virginie Boone               @vboone
# 33          US    50                 NaN                   NaN
# 34          US    20                 NaN                   NaN
# ...

# %%
US_data.groupby('taster_name')['taster_twitter_handle'].count()
# Out:
# taster_name
# Alexander Peartree            0
# Anna Lee C. Iijima            0
# California Other              1
# Carrie Dykes                  0
# Central Coast                 0
# Christina Pickard             5
# Columbia Valley               4
# El Dorado                     1
# Finger Lakes                  1
# Fiona Adams                  27
# Jim Gordon                 4175
# Joe Czerwinski              101
# Lauren Buzzeo                18
# Long Island                   2
# Matt Kettmann              6331
# Michael Schachner            71
# Napa-Sonoma                   0
# Paul Gregutt               9295
# Roger Voss                    2
# Sean P. Sullivan           4934
# Sierra Foothills              0
# Sonoma                        0
# Susan Kostrzewa             232
# Virginie Boone             9537
# Walla Walla Valley (WA)       1
# Willamette Valley             3
# Name: taster_twitter_handle, dtype: int64

# %%
len(US_data.taster_name.unique())
# Out:
# 27

# %%
US_data.taster_twitter_handle.unique()
# Out:
# array(['@paulgwine\xa0', nan, '@vboone', '@mattkettmann', '@wawinereport',
#        '@gordone_cellars', '@suskostrzewa', '@vossroger', '@bkfiona',
#        'Sierra Foothills', '@wineschach', '@JoeCz', 'Paul Gregutt',
#        'Jim Gordon', '@laurbuzz', 'Joe Czerwinski', '@winewchristina',
#        'Columbia Valley', 'Lauren Buzzeo'], dtype=object)

# %%
US_data.loc[mask_tester, : ]
# Out:
#        country price taster_name taster_twitter_handle
# 68          US    12  Jim Gordon      @gordone_cellars
# 199         US    28  Jim Gordon      @gordone_cellars
# 424         US    30  Jim Gordon      @gordone_cellars
# 433         US    27  Jim Gordon      @gordone_cellars
# 519         US    36  Jim Gordon      @gordone_cellars
# 558         US    25  Jim Gordon      @gordone_cellars
# 561         US    50  Jim Gordon      @gordone_cellars
# 571         US    25  Jim Gordon      @gordone_cellars
# 579         US    13  Jim Gordon      @gordone_cellars
# 588         US    18  Jim Gordon      @gordone_cellars
# 655         US    30  Jim Gordon      @gordone_cellars
# 661         US    15  Jim Gordon      @gordone_cellars
# 673         US    44  Jim Gordon      @gordone_cellars
# 691         US    50  Jim Gordon      @gordone_cellars
# 730         US    16  Jim Gordon      @gordone_cellars
# 806         US    27  Jim Gordon      @gordone_cellars
# ...

# %%
df.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
df[df.price =='Reserva de Familia']
# Out:
#       country                                        designation  \
# 86533   Chile   it has flat apple and lemon flavors and then ...
#
#                                   points               price province  \
# 86533   could already be past its prime.  Reserva de Familia       83
#
#       region_1           region_2 taster_name taster_twitter_handle  \
# 86533       20  Casablanca Valley         NaN                   NaN
#
#                    title      variety  \
# 86533  Michael Schachner  @wineschach
#
#                                                   winery
# 86533  Santa Carolina 2008 Reserva de Familia Chardon...

# %%
df.price
# Out:
# 0         NaN
# 1          15
# 2          14
# 3          13
# 4          65
# 5          15
# 6          16
# 7          24
# 8          12
# 9          27
# 10         19
# 11         30
# 12         34
# 13        NaN
# 14         12
# 15         24
# 16         30
# 17         13
# 18         28
# 19         32
# 20         23
# 21         20
# 22         19
# 23         22
# 24         35
# 25         69
# 26         13
# 27         10
# 28         17
# 29         16
#          ...
# 129941     20
# 129942     35
# 129943     29
# 129944     25
# 129945     20
# 129946     17
# 129947     20
# 129948     43
# 129949     35
# 129950     35
# 129951     30
# 129952     22
# 129953     25
# 129954     15
# 129955     40
# 129956     19
# 129957     17
# 129958     35
# 129959     57
# 129960     48
# 129961     30
# 129962     40
# 129963     20
# 129964    NaN
# 129965     28
# 129966     28
# 129967     75
# 129968     30
# 129969     32
# 129970     21
# ...

# %%
#Creating my perfect mask
mask_countries = (df.country == 'US')| (df.country == 'Germany') | (df.country == 'France') | (df.country == 'Israel') & (df.price < 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-94fa74848058> in <module>()
#       1 #Creating my perfect mask
# ----> 2 mask_countries = (df.country == 'US')| (df.country == 'Germany') | (df.country == 'France') | (df.country == 'Israel') & (df.price < 20)
#
# ~/.virtualenvs/datascience10/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/.virtualenvs/datascience10/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     781
#     782         if is_object_dtype(x.dtype):
# --> 783             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     784         else:
#     785
#
# ...
